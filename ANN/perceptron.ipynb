# %% [markdown]
# # perceptron formula :- y=f(x1w1 + x2w2 +.......+b)

# %%
# input
x1=5 #hours
x2=80  #attendance

# %%
# weights
w1=0.4
w2=0.02

# %%
#bias
b=1

# %%
# calculation
y=x1*w1 + x2*w2+b
y
# Out:
# 4.6

# %%
if y>=1:
    print("pass")
else:
    print("fail")
# Out:
# pass
